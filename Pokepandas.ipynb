# %%
import pandas as pd
pdata = pd.read_csv(r'C:\Users\angel\Desktop\MLcsvFiles\Pokepandas\pokemon_data.csv')
pdata
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pdata.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(pdata[['Name', 'Speed']][4:9]) #Grabbing only 5 rows
# Out:
#                         Name  Speed
# 4                 Charmander     65
# 5                 Charmeleon     80
# 6                  Charizard    100
# 7  CharizardMega Charizard X    100
# 8  CharizardMega Charizard Y    100

# %%
print(pdata[['Name', 'Generation', 'HP']])  # read each column of those types
# Out:
#                       Name  Generation  HP
# 0                Bulbasaur           1  45
# 1                  Ivysaur           1  60
# 2                 Venusaur           1  80
# 3    VenusaurMega Venusaur           1  80
# 4               Charmander           1  39
# ..                     ...         ...  ..
# 795                Diancie           6  50
# 796    DiancieMega Diancie           6  50
# 797    HoopaHoopa Confined           6  80
# 798     HoopaHoopa Unbound           6  80
# 799              Volcanion           6  80
#
# [800 rows x 3 columns]

# %%
print(pdata.iloc[1:4]) #grabs the rows in the dataframe
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
pdata.loc[pdata['Legendary'] == True] #Grab certain types !!!
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pdata.sort_values("Name", ascending =False) #data organization
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pdata.sort_values(['Name', 'HP'], ascending = [1,0]) # [acend, decend]
# more specific data organization
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pdata['Total'] = pdata['Sp. Atk'] + pdata['Attack']
# will not remove column if commented out
pdata.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    114
# 1       80     60           1      False    142
# 2      100     80           1      False    182
# 3      120     80           1      False    222

# %%
pdata = pdata.drop(columns = ['Total']) # set data frame equal to changes
# Alternative way to do this
# pdata['Total'] = df.iloc[:, 4:10].sum(axis=1) #axis = 0 is adding vertically
pdata
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pdata.iloc[1:5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pdata['sum'] = pdata['Attack'] + pdata['Defense'] + pdata['HP'] + pdata['Sp. Atk'] + pdata['Sp. Def'] + pdata['Speed']
pdata
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  sum
# 0         65       65     45           1      False  318
# ...

# %%
pdata.loc[pdata['Name'] == 'Lucario']
# Out:
#        #     Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 497  448  Lucario  Fighting  Steel  70     110       70      115       70
#
#      Speed  Generation  Legendary  sum
# 497     90           4      False  525

# %%
pdata.loc[pdata['sum'] >= 650]
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 162  150                   Mewtwo  Psychic       NaN  106     110       90
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 164  150      MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 268  248  TyranitarMega Tyranitar     Rock      Dark  100     164      150
# 269  249                    Lugia  Psychic    Flying  106      90      130
# 270  250                    Ho-oh     Fire    Flying  106     130       90
# 313  289                  Slaking   Normal       NaN  150     160      100
# 409  373  SalamenceMega Salamence   Dragon    Flying   95     145      130
# 413  376  MetagrossMega Metagross    Steel   Psychic   80     145      150
# 418  380        LatiasMega Latias   Dragon   Psychic   80     100      120
# 420  381        LatiosMega Latios   Dragon   Psychic   80     130      100
# ...

# %%
#SAVING THE DATA
#df.to_csv('modified.txt', index=False, sep='\t')

#Filtering Data (DO NOT RUN WILL ACTUALLY MODIFY)
"""
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df.reset_index(drop=True, inplace=True)

new_df

new_df.to_csv('filtered.csv')
"""
# Out:
# "\nnew_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]\n\nnew_df.reset_index(drop=True, inplace=True)\n\nnew_df\n\nnew_df.to_csv('filtered.csv')\n"

# %%
import numpy as np
def split_train_test(data, test_ratio):
    shuffled_indicies = np.random.permutation(len(data))
    test_set_size =int(len(data)*test_ratio)
    test_indicies = shuffled_indicies[:test_set_size]
    train_indicies = shuffled_indicies[test_set_size:]
    return data. iloc[train_indicies], data.iloc[test_indicies]

# %%
train_set, test_set = split_train_test(pdata, 0.2) #20% is the test_set
print(len(pdata))
print(len(train_set))
print(len(test_set))
# Out:
# 800
# 640
# 160

# %%
#We can basically do the above with sklearn with seed feature
from sklearn.model_selection import train_test_split
set_train, set_test = train_test_split(pdata, test_size =0.2, random_state =42)
print(len(set_train))
print(len(set_test))
# Out:
# 640
# 160

# %%
# Organize sum from deceding order
pdata.sort_values(["sum"], axis=0, ascending=False, inplace=True) #sorts two cols into decending
pdata['sum'].head(20)
# Out:
# 426    780
# 164    780
# 163    780
# 422    770
# 424    770
# 552    720
# 712    700
# 711    700
# 409    700
# 413    700
# 418    700
# 420    700
# 494    700
# 268    700
# 796    700
# 425    680
# 545    680
# 544    680
# 707    680
# 541    680
# Name: sum, dtype: int64

# %%
#???  Grabbing the highest sums only 
X = pdata['Generation'].head(80)
y = pdata['sum'].head(80)
# pdata.iloc[1:5] ?

X_b = np.c_[np.ones((80, 1)), X]
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
theta_best
# Out:
# array([641.50585265,   1.33669956])

# %%
X_new = np.array([[0], [6]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([641.50585265, 649.52605003])

# %%
import matplotlib.pyplot as plt

plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 7, 500, 900])
plt.show()  #Displays top 80 pokemon sums
